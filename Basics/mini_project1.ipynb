# %%
# average rating calculator
def rate_movies(**ratings):
    if not ratings:
        print("No ratings provided.")
        return
        
    total = sum(ratings.values())
    count = len(ratings)
    average = total / count
    
    print(f"🎬 {count} movies rated")
    print(f"⭐ Average Rating: {average:.1f}/10")
    print("\nRatings:")
    
    for movie, rating in ratings.items():
        stars = "★" * (rating // 2) + "☆" * (5 - rating // 2)
        print(f"{movie}: {rating}/10 {stars}")
        
        best = max(ratings, key=ratings.get)
        print(f"\n🏆 Best Movie: {best} {ratings[best]}/10")

rate_movies(Inception=9, Interstellar=8, The_Dark_Knight=10, Memento=7)
# Out:
# 🎬 4 movies rated
# ⭐ Average Rating: 8.5/10
#
# Ratings:
# Inception: 9/10 ★★★★☆
#
# 🏆 Best Movie: The_Dark_Knight 10/10
# Interstellar: 8/10 ★★★★☆
#
# 🏆 Best Movie: The_Dark_Knight 10/10
# The_Dark_Knight: 10/10 ★★★★★
#
# 🏆 Best Movie: The_Dark_Knight 10/10
# Memento: 7/10 ★★★☆☆
#
# 🏆 Best Movie: The_Dark_Knight 10/10

# %%
rate_movies()
# Out:
# No ratings provided.
