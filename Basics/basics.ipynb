# %%
# Primitive Datatypes in Python

name = "M K Chandan" # String
age = 20 # Integer
height = 5.8 # Float
is_student = True # Boolean

print(name, type(name))
print(age, type(age))
print(height, type(height))
print(is_student, type(is_student))
# Out:
# M K Chandan <class 'str'>
# 20 <class 'int'>
# 5.8 <class 'float'>
# True <class 'bool'>

# %%
# Non Primitive Datatypes in Python
# list is represented by square brackets []
# list is ordered, changeable, and allows duplicate values
langauges_known = ["C", "C++", "Python", "C"]
print(langauges_known, type(langauges_known))
# Out:
# ['C', 'C++', 'Python', 'C'] <class 'list'>

# %%
# tuple is represented by parentheses ()
# tuple is ordered, unchangeable, and allows duplicate values
fruits = ("Apple", "Banana", "Cherry", "Apple")
print(fruits, type(fruits))
# Out:
# ('Apple', 'Banana', 'Cherry', 'Apple') <class 'tuple'>

# %%
# set is represented by curly braces {}
# set is unordered, unchangeable, and does not allow duplicate values
unique_numbers = {1, 2, 3, 4, 5}
print(unique_numbers, type(unique_numbers))
# Out:
# {1, 2, 3, 4, 5} <class 'set'>

# %%
# dictionary is represented by curly braces {} with key-value pairs
# dictionary is ordered (as of Python 3.7), changeable, and does not allow duplicate keys
profile = {
    "name": "M K Chandan",
    "age": 20,
    "height": 5.8,
    "is_student": True
}
print(profile, type(profile))
# Out:
# {'name': 'M K Chandan', 'age': 20, 'height': 5.8, 'is_student': True} <class 'dict'>
